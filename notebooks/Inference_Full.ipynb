# %% [markdown]
# ### **1. Install Library**

# %%
# !pip install -q lmdb fire nltk natsort torch torchvision easyocr ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.3/338.3 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 78.2 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 65.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 27.5 MB/s eta 0:00:00

# %% [markdown]
# ### 2. **Setup EasyOCR**

# %% [markdown]
# #### Clone EasyOCR

# %%
# !git clone https://github.com/lhfazry/deep-text-recognition-benchmark
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 551, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 551 (delta 211), reused 201 (delta 201), pack-reused 321 (from 2)
# Receiving objects: 100% (551/551), 3.47 MiB | 28.67 MiB/s, done.
# Resolving deltas: 100% (330/330), done.

# %% [markdown]
# #### Pindah Direktory

# %%
# %cd deep-text-recognition-benchmark
# Out:
# /content/deep-text-recognition-benchmark

# %% [markdown]
# ### **3. Download Weight**

# %% [markdown]
# #### Download Weight YOLO

# %%
# !gdown 10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN
# !mkdir yolo_model
# !mv best.pt yolo_model
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN
# From (redirected): https://drive.google.com/uc?id=10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN&confirm=t&uuid=c3c28c5d-bd63-41aa-9c34-fd4ea825a407
# To: /content/deep-text-recognition-benchmark/best.pt
# 100% 114M/114M [00:02<00:00, 54.1MB/s]

# %% [markdown]
# #### Download Weight EasyOCR

# %%
# !gdown 1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5
# !mkdir -p saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/
# !mv best_accuracy.pth saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5
# From (redirected): https://drive.google.com/uc?id=1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5&confirm=t&uuid=5d5364c6-c2ef-46bd-b34e-e3928942ef02
# To: /content/deep-text-recognition-benchmark/best_accuracy.pth
# 100% 193M/193M [00:01<00:00, 165MB/s]

# %% [markdown]
# ### **4. Inference**

# %% [markdown]
# #### **Demo Image 1**

# %%
# !python pipeline.py \
    --image_path "demo_image/demo_image1.jpeg" \
    --Transformation TPS \
    --FeatureExtraction ResNet_CBAM \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --saved_model saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --yolo_model yolo_model/best.pt \
    --imgH 32 --imgW 100 \
    --output_channel 512 \
    --hidden_size 192 \
    --character "0123456789"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [*] Running pipeline on device: cuda
# [+] Loading YOLO model from yolo_model/best.pt...
# [+] Loading OCR model from saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth...
#
# ==================================================
# Image Path     : demo_image/demo_image1.jpeg
# Boxes Detected : 2
# --------------------------------------------------
# Stand Meter    : 02323 (Conf: 0.6847)
# Nomor Meter    : 14680096976 (Conf: 0.1194)
# ==================================================

# %% [markdown]
# #### **Demo Image 2**

# %%
# !python pipeline.py \
    --image_path "demo_image/demo_image2.jpeg" \
    --Transformation TPS \
    --FeatureExtraction ResNet_CBAM \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --saved_model saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --yolo_model yolo_model/best.pt \
    --imgH 32 --imgW 100 \
    --output_channel 512 \
    --hidden_size 192 \
    --character "0123456789"
# Out:
# [*] Running pipeline on device: cuda
# [+] Loading YOLO model from yolo_model/best.pt...
# [+] Loading OCR model from saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth...
#
# ==================================================
# Image Path     : demo_image/demo_image2.jpeg
# Boxes Detected : 2
# --------------------------------------------------
# Stand Meter    : 05615 (Conf: 0.6519)
# Nomor Meter    : 114021142679 (Conf: 0.1191)
# ==================================================

# %% [markdown]
# #### **Demo Image 3**

# %%
# !python pipeline.py \
    --image_path "demo_image/demo_image3.jpeg" \
    --Transformation TPS \
    --FeatureExtraction ResNet_CBAM \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --saved_model saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --yolo_model yolo_model/best.pt \
    --imgH 32 --imgW 100 \
    --output_channel 512 \
    --hidden_size 192 \
    --character "0123456789"
# Out:
# [*] Running pipeline on device: cuda
# [+] Loading YOLO model from yolo_model/best.pt...
# [+] Loading OCR model from saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth...
#
# ==================================================
# Image Path     : demo_image/demo_image3.jpeg
# Boxes Detected : 2
# --------------------------------------------------
# Stand Meter    : 03212 (Conf: 0.7400)
# Nomor Meter    : 4518452787 (Conf: 0.2420)
# ==================================================

# %% [markdown]
# #### **Demo Image 4**

# %%
# !python pipeline.py \
    --image_path "demo_image/demo_image4.jpeg" \
    --Transformation TPS \
    --FeatureExtraction ResNet_CBAM \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --saved_model saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --yolo_model yolo_model/best.pt \
    --imgH 32 --imgW 100 \
    --output_channel 512 \
    --hidden_size 192 \
    --character "0123456789"
# Out:
# [*] Running pipeline on device: cuda
# [+] Loading YOLO model from yolo_model/best.pt...
# [+] Loading OCR model from saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth...
#
# ==================================================
# Image Path     : demo_image/demo_image4.jpeg
# Boxes Detected : 2
# --------------------------------------------------
# Stand Meter    : 01101 (Conf: 0.6722)
# Nomor Meter    : 50906455751 (Conf: 0.0640)
# ==================================================
