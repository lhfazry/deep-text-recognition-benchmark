# %% [markdown]
# ### **1. Install Library**

# %%
# !pip install -q lmdb fire nltk natsort torch torchvision easyocr ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 338.3/338.3 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 68.7 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 59.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 34.1 MB/s eta 0:00:00

# %% [markdown]
# ### 2. **Setup EasyOCR**

# %% [markdown]
# #### Clone EasyOCR

# %%
# !git clone https://github.com/lhfazry/deep-text-recognition-benchmark
# Out:
# Cloning into 'deep-text-recognition-benchmark'...
# remote: Enumerating objects: 541, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 541 (delta 234), reused 234 (delta 215), pack-reused 274 (from 1)
# Receiving objects: 100% (541/541), 3.30 MiB | 8.92 MiB/s, done.
# Resolving deltas: 100% (334/334), done.

# %% [markdown]
# #### Pindah Direktory

# %%
# %cd deep-text-recognition-benchmark
# Out:
# /content/deep-text-recognition-benchmark

# %% [markdown]
# ### **3. Download Weight**

# %% [markdown]
# #### Download Weight YOLO

# %%
# !gdown 10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN
# !mkdir yolo_model
# !mv best.pt yolo_model
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN
# From (redirected): https://drive.google.com/uc?id=10a4YLV7E-HOUhDMz8Dy5v8L3l_27XEkN&confirm=t&uuid=e2a4d516-f504-4279-ad53-4b50ea2d999f
# To: /content/deep-text-recognition-benchmark/best.pt
# 100% 114M/114M [00:03<00:00, 37.3MB/s]

# %% [markdown]
# #### Download Weight EasyOCR

# %%
# !gdown 1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5
# !mkdir -p saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/
# !mv best_accuracy.pth saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5
# From (redirected): https://drive.google.com/uc?id=1HC4J54YfOomADtA2-GGgSkiRTNGo-hf5&confirm=t&uuid=536b9d96-5318-407e-9a4b-44ba87c10adc
# To: /content/deep-text-recognition-benchmark/best_accuracy.pth
# 100% 193M/193M [00:03<00:00, 56.0MB/s]

# %% [markdown]
# ### **4. Inference**

# %%
# !python pipeline.py \
    --image_path "demo_image/demo_image1.jpeg" \
    --Transformation TPS \
    --FeatureExtraction ResNet_CBAM \
    --SequenceModeling BiLSTM \
    --Prediction CTC \
    --saved_model saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth \
    --yolo_model yolo_model/best.pt \
    --imgH 32 --imgW 100 \
    --output_channel 512 \
    --hidden_size 256 \
    --character "0123456789"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# [*] Running pipeline on device: cuda
# [+] Loading YOLO model from yolo_model/best.pt...
# [+] Loading OCR model from saved_model/TPS-ResNet-BiLSTM-CTC-Seed1111/best_accuracy.pth...
# Traceback (most recent call last):
#   File "/content/deep-text-recognition-benchmark/pipeline.py", line 230, in <module>
#     pipeline = KilometerPipeline(
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/deep-text-recognition-benchmark/pipeline.py", line 48, in __init__
#     self.ocr_model.load_state_dict(torch.load(ocr_model_path, map_location=self.device))
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 2639, in load_state_dict
#     raise RuntimeError(
# RuntimeError: Error(s) in loading state_dict for DataParallel:
# 	Unexpected key(s) in state_dict: "module.FeatureExtraction.ConvNet.layer1.0.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer1.0.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer1.0.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer2.0.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer2.0.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer2.0.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer2.1.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer2.1.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer2.1.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer3.0.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer3.0.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer3.0.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer3.1.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer3.1.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer3.1.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer3.2.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer3.2.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer3.2.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer3.3.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer3.3.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer3.3.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer3.4.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer3.4.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer3.4.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer4.0.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer4.0.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer4.0.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer4.1.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer4.1.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer4.1.cbam.sa.conv1.weight", "module.FeatureExtraction.ConvNet.layer4.2.cbam.ca.fc1.weight", "module.FeatureExtraction.ConvNet.layer4.2.cbam.ca.fc2.weight", "module.FeatureExtraction.ConvNet.layer4.2.cbam.sa.conv1.weight".
# 	size mismatch for module.Transformation.GridGenerator.P_hat: copying a param with shape torch.Size([3200, 23]) from checkpoint, the shape in current model is torch.Size([12800, 23]).

# %%
# !ls
# Out:
# create_lmdb_dataset.py	figures       pipeline.py	  saved_model
# dataset.py		inference.py  plot_logs.py	  test.py
# demo_image		LICENSE.md    __pycache__	  train.py
# demo.ipynb		model.py      README.md		  utils.py
# demo.py			modules       README_pipeline.md  yolo_model
